# %%
with open("../../../transformers/test.txt",'r') as o ,open("../../../transformers/germeval-model/test_predictions1.txt",'r') as p:
    o_lines = o.readlines()
    articles = []
    running_article = []
    running_sentence = []
    articles_p = []
    running_article_p = []
    running_sentence_p = []
    for line in o_lines[:100000]:
        
        if "EOA" in line:
            articles.append(running_article)
            running_article = []
            articles_p.append(running_article_p)
            running_article_p = []
            
        if "EOS" in line:
            running_article.append(running_sentence)
            running_sentence = []
            running_article_p.append(running_sentence_p)
            running_sentence_p = []
            
        
        
#         if "SOS" not in line and "SOA" not in line and "EOS" not in line and "EOA" not in line:
#         original_line = line.replace("\n","")
#         prediction = p.readline().replace("\n","")[-1]
#         if len(original_line) > 0
        running_sentence.append(line.replace("\n",""))
        running_sentence_p.append(p.readline().replace("\n",""))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-33247de1622a> in <module>
# ----> 1 with open("../../../transformers/test.txt",'r') as o ,open("../../../transformers/germeval-model/test_predictions1.txt",'r') as p:
#       2     o_lines = o.readlines()
#       3     articles = []
#       4     running_article = []
#       5     running_sentence = []
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../transformers/germeval-model/test_predictions1.txt'

# %%
articles_p
# Out:
# [[['Unbelievable! O', '', 'Sharia O'],
#   ['New O',
#    'Mexico: O',
#    'Islamic O',
#    'compound O',
#    'jihadis O',
#    'RELEASED O',
#    'on O',
#    'bond O',
#    'after O',
#    'charges O',
#    'of O',
#    '“Islamophobia” O',
#    'and O',
#    '“racism” O',
#    '(Islam O',
#    'is O',
#    'not O',
#    'a O',
#    'race) O',
#    '',
#    "Editor's O",
#    'Note: O',
#    'Talk O',
#    '',
#    'There O',
#    'were I',
#    'remains I',
#    'of I',
#    'a I'],
#   ['4-year-old O',
#    'boy O',
#    'found O',
#    'there, O',
#    'who O',
#    'allegedly O',
#    'died O',
#    'while O',
#    'they O',
#    'were O',
#    'performing O',
#    'some O',
#    'sort I',
#    'of I',
#    'Islamic I',
#    'ritual I',
#    'over I',
#    'him. I',
#    '',
#    'The I',
#    'Bundys I',
#    'and I',
#    'their I',
#    'supporters I',
#    'got O',
#    'nearly I'],
#   ['two I',
#    'years I',
#    'in I',
#    'jail I',
#    'and I',
#    'no I',
# ...
